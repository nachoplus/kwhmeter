# %% [markdown]
# ## EREDES:  Pruebas del modulo de acceso a los datos de contador

# %%
import pandas as pd
from kwhmeter import suministro,contador, timezone, append_prices, read_config
from datetime import datetime, timedelta

# %%
credenciales=read_config()
credenciales['alarcon']
# Out:
# {'distribuidora': 'eredes', 'password': '4re0Rk0?', 'user': '50835060T'}
